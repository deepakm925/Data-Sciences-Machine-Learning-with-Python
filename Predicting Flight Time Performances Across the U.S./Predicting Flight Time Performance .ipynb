# %% [markdown]
# # PROJECT : PREDICTING FLIGHT TIME PERFORMANCES ACROSS THE U.S.

# %% [markdown]
# ## Project Overview:
#
# The purpose of this Project is to analyze and predict flight time performances across the United States of America.
#
# (The dataset used consists of domestic flight information only).

# %% [markdown]
# ### Reading into the Dataset
# In this first step we will read into the dataset and import the few necessary modules.

# %%
import numpy as np
import pandas as pd
from IPython.display import display 
# %matplotlib inline 

data = "flight_data.csv"
load_data = pd.read_csv(data)
flight_data = load_data

print("Data loaded Successfully")
print("The data has {} samples with {} features each".format(*flight_data.shape))
# Out:
# Data loaded Successfully
# The data has 445827 samples with 110 features each

# %%
flight_data.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2016        1      1           6          3  2016-01-06            AA
# 1  2016        1      1           7          4  2016-01-07            AA
# 2  2016        1      1           8          5  2016-01-08            AA
# 3  2016        1      1           9          6  2016-01-09            AA
# 4  2016        1      1          10          7  2016-01-10            AA
#
#    AirlineID Carrier TailNum      ...       Div4TailNum  Div5Airport  \
# 0      19805      AA  N4YBAA      ...               NaN          NaN
# 1      19805      AA  N434AA      ...               NaN          NaN
# 2      19805      AA  N541AA      ...               NaN          NaN
# 3      19805      AA  N489AA      ...               NaN          NaN
# 4      19805      AA  N439AA      ...               NaN          NaN
#
#    Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# ...

# %% [markdown]
# After we have finished loading and reading into the dataset. We can expirment and learn general information from the data. One simple way of analyzing a database is by describing the data, Like below:

# %%
display(flight_data.describe())
# Out:
#            Year   Quarter     Month     DayofMonth      DayOfWeek  \
# count  445827.0  445827.0  445827.0  445827.000000  445827.000000
# mean     2016.0       1.0       1.0      15.893510       4.113815
# std         0.0       0.0       0.0       8.936692       2.005007
# min      2016.0       1.0       1.0       1.000000       1.000000
# 25%      2016.0       1.0       1.0       8.000000       2.000000
# 50%      2016.0       1.0       1.0      16.000000       4.000000
# 75%      2016.0       1.0       1.0      24.000000       6.000000
# max      2016.0       1.0       1.0      31.000000       7.000000
#
#            AirlineID      FlightNum  OriginAirportID  OriginAirportSeqID  \
# count  445827.000000  445827.000000    445827.000000        4.458270e+05
# mean    19903.085069    2078.856456     12682.120789        1.268215e+06
# std       382.853084    1757.269780      1529.485604        1.529483e+05
# min     19393.000000       1.000000     10135.000000        1.013503e+06
# ...

# %% [markdown]
# #### Identifying Missing Values in the Dataset
#
# In this step we will analyze to see if there are any missing values within the dataset.
